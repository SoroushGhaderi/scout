# %%
import pandas as pd
import os
import zipfile
from constants import file_path

# %%
os.listdir(file_path["save_data_path"])
# Out:
# ['raw_statistics_parquet',
#  'raw_match_parquet',
#  'raw_point_by_point_parquet',
#  'raw_odds_parquet',
#  'raw_votes_parquet',
#  'raw_tennis_power_parquet']

# %%
os.path.join(file_path["save_data_path"], filename)
# Out:
# '../../data/raw/raw_statistics_parquet'

# %%
os.chdir(file_path["save_data_path"])

# %%
# zip 6 raw folders
with zipfile.ZipFile("2023.zip", "w") as zip_file:
    for filename in os.listdir():
        if os.path.isdir(filename):
            zip_file.write(filename)

# %%
for filename in os.listdir():
    if os.path.isdir(filename):
        os.rmdir(filename)

# %%
# zip 6 raw folders
with zipfile.ZipFile("2023.zip", "w") as zip_file:
    for filename in os.listdir():
        if os.path.isdir(filename):
            zip_file.write(filename)

# remove 6 raw folders
for filename in os.listdir():
    if os.path.isdir(os.path.join(file_path["save_data_path"], filename)):
        os.rmdir(os.path.join(file_path["save_data_path"], filename))
